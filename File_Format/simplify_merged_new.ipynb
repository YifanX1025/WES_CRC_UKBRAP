# %%
# Simplify VCF files for chromosomes 1-22 using swiss-army-knife
import subprocess

# %%
# Configuration
chromosomes = list(range(1, 23))  # 1 to 22
files_processed = []
files_failed = []

# %%
# DNAnexus paths - update these according to your project
dx_input_path = "project-GyJ14jjJxy674xQ2pGQ5G3K6:/Step2_vcf_merged_500k/"  # Input VCF directory
dx_output_path = "project-GyJ14jjJxy674xQ2pGQ5G3K6:/Step2_vcf_merged_500k_simplified/"  # Output destination
tag_str = "bcftools_simplify_vcfs"

# %%
print("=" * 60)
print("SIMPLIFYING VCF FILES FOR CHROMOSOMES 1-22")
print("=" * 60)
# Out:
# ============================================================
# SIMPLIFYING VCF FILES FOR CHROMOSOMES 1-22
# ============================================================

# %%
for chrom in chromosomes:
    chrom_str = str(chrom)
    
    # Input and output file names
    input_vcf = f"ukb23157_c{chrom_str}_merged_v1_staar_trimmed.vcf.gz"
    input_index = f"ukb23157_c{chrom_str}_merged_v1_staar_trimmed.vcf.gz.tbi"
    output_vcf = f"c{chrom_str}_merged_simplified.vcf.gz"
    output_index = f"c{chrom_str}_merged_simplified.vcf.gz.tbi"
    
    print(f"Processing chromosome {chrom_str}: {input_vcf} -> {output_vcf}")
    
    try:
        # Instance type - mem1_ssd1_v2_x2 should be sufficient for bcftools operations
        mem_level = "mem1_ssd1_v2_x2"
        
        # BCFtools command pipeline - FIXED: Using escaped quotes for proper shell execution
        bcftools_cmd = (
            f'echo \\"=== Processing chromosome {chrom_str} ===\\" && '
            f'pwd && ls -la && '
            f'echo \\"Input files available:\\" && '
            f'ls -la {input_vcf} && '
            
            # BCFtools pipeline: view -G | annotate | bgzip
            f'bcftools view -G {input_vcf} | '
            f'bcftools annotate -x INFO,ID,QUAL,FILTER | '
            f'bgzip -c > {output_vcf} && '
            
            # Create index
            f'bcftools index -t {output_vcf} && '
            
            # Verify outputs
            f'echo \\"Output files created:\\" && '
            f'ls -la {output_vcf}* && '
            f'echo \\"File sizes:\\" && '
            f'du -h {output_vcf}* && '
            f'echo \\"=== Chromosome {chrom_str} completed successfully ===\\"'
        )
        
        # Input file specification
        dx_input_str = (
            f'-iin="{dx_input_path}{input_vcf}" '
            f'-iin="{dx_input_path}{input_index}"'
        )
        
        # Final dx command
        dx_command = (
            f'dx run app-swiss-army-knife '
            f'--instance-type {mem_level} '
            f'--priority normal '
            f'-y --brief '
            f'{dx_input_str} '
            f'-icmd="{bcftools_cmd}" '
            f'--destination {dx_output_path} '
            f'--tag "{tag_str}" '
            f'--name "BCFtools_simplify_chr{chrom_str}" '
            f'--property chromosome={chrom_str}'
        )
        
        print(f"Instance type: {mem_level}")
        print("✅ BCFtools view -G (remove genotypes)")
        print("✅ BCFtools annotate -x INFO,ID,QUAL,FILTER (remove fields)")
        print("✅ BGzip compression + tabix indexing")
        print("-" * 40)
        
        print(f"Submitting job for chromosome {chrom_str}...")
        
        # Execute the command - using ! for Jupyter notebook execution
        # !{dx_command}
        
        print(f"✅ Successfully submitted chromosome {chrom_str}")
        files_processed.append(chrom_str)
            
    except Exception as e:
        print(f"❌ Exception processing chromosome {chrom_str}: {str(e)}")
        files_failed.append(chrom_str)
    
    print("=" * 60)

print("\n" + "=" * 60)
print("PROCESSING SUMMARY")
print("=" * 60)
print(f'Chromosomes successfully submitted: {len(files_processed)}')
print(f'Chromosomes that failed: {len(files_failed)}')

if files_processed:
    print(f'\n✅ Successfully processed chromosomes: {", ".join(files_processed)}')

if files_failed:
    print(f'\n❌ Failed chromosomes: {", ".join(files_failed)}')

print(f"\n📊 All jobs submitted with tag: {tag_str}")
print(f"🔍 Monitor progress with: dx find jobs --tag {tag_str}")
print(f"📁 Output files will be saved to: {dx_output_path}")

# Additional monitoring commands
print("\n" + "=" * 60)
print("USEFUL MONITORING COMMANDS")
print("=" * 60)
print(f"# Check job status:")
print(f"dx find jobs --tag {tag_str} --state running")
print(f"dx find jobs --tag {tag_str} --state done")
print(f"dx find jobs --tag {tag_str} --state failed")
print("")
print(f"# Check output files:")
print(f"dx ls {dx_output_path}")
print("")
print(f"# Download a specific file:")
print(f"dx download {dx_output_path}c1_merged_simplified.vcf.gz")
print("=" * 60)
# Out:
# Processing chromosome 1: ukb23157_c1_merged_v1_staar_trimmed.vcf.gz -> c1_merged_simplified.vcf.gz
# Instance type: mem1_ssd1_v2_x2
# ✅ BCFtools view -G (remove genotypes)
# ✅ BCFtools annotate -x INFO,ID,QUAL,FILTER (remove fields)
# ✅ BGzip compression + tabix indexing
# ----------------------------------------
# Submitting job for chromosome 1...
# job-J2fQ4F0Jxy6Kk07qj91bggFJ
# ✅ Successfully submitted chromosome 1
# ============================================================
# Processing chromosome 2: ukb23157_c2_merged_v1_staar_trimmed.vcf.gz -> c2_merged_simplified.vcf.gz
# Instance type: mem1_ssd1_v2_x2
# ✅ BCFtools view -G (remove genotypes)
# ✅ BCFtools annotate -x INFO,ID,QUAL,FILTER (remove fields)
# ✅ BGzip compression + tabix indexing
# ----------------------------------------
# Submitting job for chromosome 2...
# job-J2fQ4F8Jxy6Fj26v8xfFbbgz
# ✅ Successfully submitted chromosome 2
# ============================================================
# Processing chromosome 3: ukb23157_c3_merged_v1_staar_trimmed.vcf.gz -> c3_merged_simplified.vcf.gz
# Instance type: mem1_ssd1_v2_x2
# ✅ BCFtools view -G (remove genotypes)
# ✅ BCFtools annotate -x INFO,ID,QUAL,FILTER (remove fields)
# ✅ BGzip compression + tabix indexing
# ----------------------------------------
# Submitting job for chromosome 3...
# job-J2fQ4FjJxy655pQYpkXxbZb1
# ✅ Successfully submitted chromosome 3
# ============================================================
# Processing chromosome 4: ukb23157_c4_merged_v1_staar_trimmed.vcf.gz -> c4_merged_simplified.vcf.gz
# Instance type: mem1_ssd1_v2_x2
# ✅ BCFtools view -G (remove genotypes)
# ✅ BCFtools annotate -x INFO,ID,QUAL,FILTER (remove fields)
# ✅ BGzip compression + tabix indexing
# ----------------------------------------
# Submitting job for chromosome 4...
# job-J2fQ4G0Jxy69J04F3ky0G5K1
# ✅ Successfully submitted chromosome 4
# ============================================================
# Processing chromosome 5: ukb23157_c5_merged_v1_staar_trimmed.vcf.gz -> c5_merged_simplified.vcf.gz
# Instance type: mem1_ssd1_v2_x2
# ✅ BCFtools view -G (remove genotypes)
# ✅ BCFtools annotate -x INFO,ID,QUAL,FILTER (remove fields)
# ✅ BGzip compression + tabix indexing
# ----------------------------------------
# Submitting job for chromosome 5...
# job-J2fQ4GQJxy66581gPbJgzX2f
# ✅ Successfully submitted chromosome 5
# ============================================================
# Processing chromosome 6: ukb23157_c6_merged_v1_staar_trimmed.vcf.gz -> c6_merged_simplified.vcf.gz
# Instance type: mem1_ssd1_v2_x2
# ✅ BCFtools view -G (remove genotypes)
# ✅ BCFtools annotate -x INFO,ID,QUAL,FILTER (remove fields)
# ✅ BGzip compression + tabix indexing
# ----------------------------------------
# Submitting job for chromosome 6...
# job-J2fQ4GjJxy69J04F3ky0G5K4
# ✅ Successfully submitted chromosome 6
# ============================================================
# Processing chromosome 7: ukb23157_c7_merged_v1_staar_trimmed.vcf.gz -> c7_merged_simplified.vcf.gz
# Instance type: mem1_ssd1_v2_x2
# ✅ BCFtools view -G (remove genotypes)
# ✅ BCFtools annotate -x INFO,ID,QUAL,FILTER (remove fields)
# ✅ BGzip compression + tabix indexing
# ----------------------------------------
# Submitting job for chromosome 7...
# job-J2fQ4J8Jxy655pQYpkXxbZb7
# ✅ Successfully submitted chromosome 7
# ============================================================
# Processing chromosome 8: ukb23157_c8_merged_v1_staar_trimmed.vcf.gz -> c8_merged_simplified.vcf.gz
# Instance type: mem1_ssd1_v2_x2
# ✅ BCFtools view -G (remove genotypes)
# ✅ BCFtools annotate -x INFO,ID,QUAL,FILTER (remove fields)
# ✅ BGzip compression + tabix indexing
# ----------------------------------------
# Submitting job for chromosome 8...
